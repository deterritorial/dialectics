# %% [markdown]
# # totality

# %%
# !pip install totality
from totality import Text

# %%
# If I start a new text
t = Text(title="Frankenstein", author="Shelley")
t
# Out:
# Shelley, FRANKENSTEIN [_tmp/T78577] <tQj8B>

# %%
# Not much metadata so far
t.meta
# Out:
# {'au': 'Shelley',
#  'ti': 'Frankenstein',
#  'title': 'Frankenstein',
#  'author': 'Shelley'}

# %%
# No text access
t.txt
# Out:
# ''

# %%
# But if I find copies elsewhere
t.find_copies()
# Out:
# [19:29:29.475] Relating texts (as {rel}):   0%|          | 0/39 [00:00<?, ?it/s]
# {Shelley, FRANKENSTEIN (1818) [_chadwyck/Nineteenth-Century_Fiction/ncf3206.04] <FgwS6>,
#  Shelley, FRANKENSTEIN (1818) [_clmet/CLMET3_1_2_155] <Nzhx4>,
#  Shelley, FRANKENSTEIN (1818) [_litlab/LL4539] <sqEhn>,
#  Shelley, FRANKENSTEIN (1818) [_semantic_cohort/SC0473] <pEW4u>,
#  Shelley, FRANKENSTEIN (1818) [_txtlab/EN_1818_Shelley,Mary_Frankenstein_Novel] <72PIU>,
#  Shelley, FRANKENSTEIN (1831) [_chadwyck/Nineteenth-Century_Fiction/ncf3206.03] <w8wuL>,
#  Shelley, FRANKENSTEIN (1831) [_semantic_cohort/SC0728] <uBUsH>}

# %%
# I can pool their metadata
t.metadata()
# Out:
# {'_id': 'text/tQj8B',
#  '_key': 'tQj8B',
#  '_addr': '_tmp/T78577',
#  '_corpus': 'tmp',
#  'id': 'T78577',
#  'au': 'Shelley',
#  'ti': 'Frankenstein',
#  'title': ['Frankenstein',
#   'Frankenstein Or The Modern Prometheus By the Author of The Last Man Revised Corrected And Illustrated With A New Introduction By The Author',
#   'Frankenstein, or the Modern Prometheus',
#   'Frankenstein or The Modern Prometheus In Three Volumes',
#   'Frankenstein; or The Modern Prometheus',
#   'Frankenstein: Or, The Modern Prometheus ... Revised, Corrected, And Illustrated With A New Introduction, By the Author.',
#   'Frankenstein; or The Modern Prometheus. In Three Volumes.'],
#  'author': ['Shelley',
#   'Shelley, Mary Wollstonecraft',
#   'Shelley, Mary Wollstonecraft (Godwin) ',
#   'Shelley, Mary Wollstonecraft, 1797&ndash;1851',
#   'Shelley,Mary'],
#  'author_birth': 1797,
#  'author_dob': 1797,
#  'author_dod': 1851,
#  'author_gender': 'F',
#  'author_id': 756,
#  'author_name_first': 'Mary',
#  'author_name_last': 'Shelley',
#  'author_name_middle': 'Wollstonecraft Godwin',
#  'author_nation': 'English',
#  'corpus': ['CLMET', 'LitLab'],
#  'date': 1818,
#  'decade': '1810s',
#  'downloaded': '04-02-2013',
#  'file': 'CLMET3_1_2_155.txt',
#  'fn_raw': ['Nineteenth-Century_Fiction/ncf3206.04.new',
#   'Nineteenth-Century_Fiction/ncf3206.03.new'],
#  'freq_absval': ['0.83%', '0.81%'],
#  'freq_hardseed': ['2.94%', '2.82%'],
#  'gender': ['F', 'female'],
#  'genre': ['Fiction', 'Gothic'],
#  'id_orig': [155, 182],
#  'idref': ['Z200043462', 'Z200043428'],
#  'language': 'English',
#  'length': 75567,
#  'medium': ['Prose', 'Fiction'],
#  'name': ['PREFACE.', 'INTRODUCTION.'],
#  'nation': 'British',
#  'notes': 'Epistolary novel',
#  'num_words': [72584, 72610],
#  'ocr_accuracy': [0.99231235534, 0.9885966120370001],
#  'period': '1780-1850',
#  'person': 'third',
#  'pub': ['Printed for Lackington, Hughes, Harding, Mavor &amp; Jones',
#   'Henry Colburn and Richard Bentley'],
#  'q_absval': 'Q4',
#  'q_hardseed': 'Q1',
#  'quartcent': '1800-1824',
#  'sheetname': 'corpus-metadata.LitLab.txt',
#  'source': ['http://www.gutenberg.org/files/41445/41445-h/41445-h.htm',
#   'Allison, Sarah, Ryan Heuser, Matthew Jockers, Franco Moretti, Michael Witmore. â€œQuantitative Formalism: an Experiment.â€\x9d Stanford: Stanford Literary Lab, 2011. Print.|Literary Lab Corpus I'],
#  'subcorpus': 'Nineteenth-Century_Fiction',
#  'subgenre': 'fict',
#  'type': 'BOOK',
#  'year': [1831, 1818],
#  'yr': [1831, 1818],
#  'z_absval': [0.66, 0.58],
#  'z_hardseed': [-1.23, -1.32]}

# %%
# Grab the txt file
t.txt[:280]
# Out:
# 'The event on which this fiction is\nfounded has been supposed, by Dr.\nDarwin, and some of the physiological\nwriters of Germany, as not\nof impossible occurrence. I shall\nnot be supposed as according the\nremotest degree of serious faith to\nsuch an imagination; yet, in assuming\nit as'

# %%
# tokenize it...
t.tokens()[:25]
# Out:
# ['the',
#  'event',
#  'on',
#  'which',
#  'this',
#  'fiction',
#  'is',
#  'founded',
#  'has',
#  'been',
#  'supposed',
#  'by',
#  'dr',
#  'darwin',
#  'and',
#  'some',
#  'of',
#  'the',
#  'physiological',
#  'writers',
#  'of',
#  'germany',
#  'as',
#  'not',
#  'of']

# %%
# count words
t.counts()
# Out:
# Counter({'the': 4021,
#          'event': 17,
#          'on': 431,
#          'which': 550,
#          'this': 415,
#          'fiction': 2,
#          'is': 321,
#          'founded': 4,
#          'has': 67,
#          'been': 192,
#          'supposed': 12,
#          'by': 446,
#          'dr': 1,
#          'darwin': 1,
#          'and': 2891,
#          'some': 157,
#          'of': 2505,
#          'physiological': 1,
#          'writers': 3,
#          'germany': 3,
#          'as': 507,
#          'not': 523,
#          'impossible': 12,
#          'occurrence': 5,
#          'i': 2782,
#          'shall': 105,
#          'be': 364,
#          'according': 3,
#          'remotest': 2,
#          'degree': 23,
#          'serious': 3,
#          'faith': 3,
#          'to': 1961,
#          'such': 81,
#          'an': 213,
#          'imagination': 25,
#          'yet': 160,
#          'in': 1069,
#          'assuming': 1,
#          'it': 520,
#          'basis': 1,
#          'a': 1302,
#          'work': 34,
#          'fancy': 12,
#          'have': 364,
#          'considered': 12,
#          'myself': 126,
#          'merely': 6,
#          'weaving': 1,
#          'series': 6,
#          'supernatural': 6,
#          'terrors': 2,
#          'interest': 17,
#          'story': 15,
#          'depends': 1,
#          'exempt': 2,
#          'from': 363,
#          'disadvantages': 1,
#          'mere': 3,
#          'tale': 32,
#          'spectres': 1,
#          'or': 172,
#          'enchantment': 1,
#          'was': 984,
#          'recommended': 2,
#          'novelty': 2,
#          'situations': 4,
#          'developes': 1,
#          'however': 35,
#          'physical': 3,
#          'fact': 5,
#          'affords': 2,
#          'point': 15,
#          'view': 17,
#          'for': 481,
#          'delineating': 1,
#          'human': 60,
#          'passions': 9,
#          'more': 160,
#          'comprehensive': 2,
#          'commanding': 1,
#          'than': 113,
#          'any': 96,
#          'ordinary': 5,
#          'relations': 4,
#          'existing': 4,
#          'events': 19,
#          'can': 95,
#          'yield': 2,
#          'thus': 51,
#          'endeavoured': 29,
#          'preserve': 6,
#          'truth': 13,
#          'elementary': 2,
#          'principles': 2,
#          'nature': 47,
#          'while': 55,
#          'scrupled': 1,
#          'innovate': 1,
#          'upon': 123,
#          'their': 145,
#          'combinations': 2,
#          'iliad': 1,
#          'tragic': 1,
#          'poetry': 4,
#          'greece': 3,
#          'shakespeare': 2,
#          'tempest': 3,
#          'mid': 1,
#          'summer': 11,
#          "night's": 2,
#          'dream': 16,
#          'most': 88,
#          'especially': 5,
#          'milton': 1,
#          'paradise': 6,
#          'lost': 34,
#          'conform': 1,
#          'rule': 4,
#          'humble': 1,
#          'novelist': 1,
#          'who': 173,
#          'seeks': 1,
#          'confer': 2,
#          'receive': 7,
#          'amusement': 8,
#          'his': 497,
#          'labours': 17,
#          'may': 104,
#          'without': 28,
#          'presumption': 3,
#          'apply': 9,
#          'prose': 1,
#          'licence': 1,
#          'rather': 23,
#          'adoption': 1,
#          'so': 209,
#          'many': 69,
#          'exquisite': 5,
#          'feeling': 27,
#          'resulted': 2,
#          'highest': 4,
#          'specimens': 1,
#          'circumstance': 11,
#          'my': 1680,
#          'rests': 4,
#          'suggested': 4,
#          'casual': 1,
#          'conversation': 19,
#          'commenced': 7,
#          'partly': 12,
#          'source': 5,
#          'expedient': 1,
#          'exercising': 1,
#          'untried': 1,
#          'resources': 3,
#          'mind': 87,
#          'other': 74,
#          'motives': 6,
#          'were': 290,
#          'mingled': 4,
#          'with': 645,
#          'these': 158,
#          'proceeded': 18,
#          'am': 127,
#          'no': 162,
#          'means': 25,
#          'indifferent': 1,
#          'manner': 33,
#          'whatever': 4,
#          'moral': 2,
#          'tendencies': 1,
#          'exist': 7,
#          'sentiments': 6,
#          'characters': 4,
#          'contains': 1,
#          'affect': 1,
#          'reader': 1,
#          'chief': 6,
#          'concern': 2,
#          'respect': 5,
#          'limited': 1,
#          'avoiding': 1,
#          'enervating': 1,
#          'effects': 9,
#          'novels': 1,
#          'present': 30,
#          'day': 86,
#          'exhibition': 1,
#          'amiableness': 1,
#          'domestic': 11,
#          'affection': 38,
#          'excellence': 3,
#          'universal': 2,
#          'virtue': 13,
#          'opinions': 3,
#          'naturally': 2,
#          'spring': 15,
#          'character': 8,
#          'situation': 12,
#          'hero': 2,
#          'are': 165,
#          'conceived': 14,
#          'always': 30,
#          'own': 105,
#          'conviction': 5,
#          'nor': 23,
#          'inference': 1,
#          'justly': 1,
#          'drawn': 4,
#          'following': 10,
#          'pages': 1,
#          'prejudicing': 1,
#          'philosophical': 2,
#          'doctrine': 2,
#          'kind': 31,
#          'subject': 18,
#          'also': 67,
#          'additional': 5,
#          'author': 6,
#          'that': 1024,
#          'begun': 3,
#          'majestic': 6,
#          'region': 5,
#          'where': 81,
#          'scene': 49,
#          'principally': 5,
#          'laid': 2,
#          'society': 15,
#          'cannot': 50,
#          'cease': 7,
#          'regretted': 3,
#          'passed': 64,
#          '1816': 1,
#          'environs': 6,
#          'geneva': 39,
#          'season': 10,
#          'cold': 32,
#          'rainy': 1,
#          'evenings': 1,
#          'we': 200,
#          'crowded': 3,
#          'around': 30,
#          'blazing': 1,
#          'wood': 26,
#          'fire': 26,
#          'occasionally': 1,
#          'amused': 3,
#          'ourselves': 2,
#          'german': 2,
#          'stories': 1,
#          'ghosts': 2,
#          'happened': 10,
#          'fall': 9,
#          'into': 118,
#          'our': 118,
#          'hands': 33,
#          'tales': 3,
#          'excited': 13,
#          'us': 61,
#          'playful': 2,
#          'desire': 29,
#          'imitation': 3,
#          'two': 44,
#          'friends': 53,
#          'pen': 1,
#          'one': 194,
#          'whom': 81,
#          'would': 176,
#          'far': 39,
#          'acceptable': 1,
#          'public': 7,
#          'thing': 24,
#          'ever': 77,
#          'hope': 49,
#          'produce': 5,
#          'agreed': 6,
#          'write': 8,
#          'each': 20,
#          'weather': 10,
#          'suddenly': 22,
#          'became': 60,
#          'serene': 7,
#          'left': 30,
#          'me': 804,
#          'journey': 31,
#          'among': 44,
#          'alps': 6,
#          'magnificent': 8,
#          'scenes': 14,
#          'they': 193,
#          'all': 181,
#          'memory': 18,
#          'ghostly': 1,
#          'visions': 6,
#          'only': 126,
#          'completed': 4,
#          'st': 6,
#          'petersburgh': 3,
#          'dec': 1,
#          '11th': 2,
#          '17': 10,
#          'wblank': 13,
#          'you': 574,
#          'will': 187,
#          'rejoice': 1,
#          'hear': 18,
#          'disaster': 3,
#          'accompanied': 9,
#          'commencement': 4,
#          'enterprise': 6,
#          'regarded': 5,
#          'evil': 24,
#          'forebodings': 2,
#          'arrived': 30,
#          'here': 30,
#          'yesterday': 3,
#          'first': 101,
#          'task': 14,
#          'assure': 5,
#          'dear': 73,
#          'sister': 27,
#          'welfare': 3,
#          'increasing': 1,
#          'confidence': 7,
#          'success': 10,
#          'undertaking': 11,
#          'already': 33,
#          'north': 12,
#          'london': 7,
#          'walk': 5,
#          'streets': 6,
#          'feel': 52,
#          'northern': 6,
#          'breeze': 10,
#          'play': 7,
#          'cheeks': 8,
#          'braces': 1,
#          'nerves': 4,
#          'fills': 5,
#          'delight': 33,
#          'do': 125,
#          'understand': 15,
#          'travelled': 7,
#          'regions': 4,
#          'towards': 91,
#          'advancing': 3,
#          'gives': 5,
#          'foretaste': 1,
#          'those': 83,
#          'icy': 2,
#          'climes': 1,
#          'inspirited': 3,
#          'wind': 27,
#          'promise': 26,
#          'dreams': 14,
#          'become': 33,
#          'fervent': 1,
#          'vivid': 4,
#          'try': 6,
#          'vain': 10,
#          'persuaded': 9,
#          'pole': 4,
#          'seat': 5,
#          'frost': 5,
#          'desolation': 5,
#          'presents': 3,
#          'itself': 21,
#          'beauty': 23,
#          'there': 69,
#          'margaret': 10,
#          'sun': 47,
#          'visible': 6,
#          'its': 107,
#          'broad': 2,
#          'disk': 2,
#          'just': 17,
#          'skirting': 1,
#          'horizon': 6,
#          'diffusing': 1,
#          'perpetual': 5,
#          'splendour': 1,
#          'your': 254,
#          'leave': 22,
#          'put': 14,
#          'trust': 9,
#          'preceding': 6,
#          'navigators': 3,
#          'snow': 15,
#          'banished': 6,
#          'sailing': 1,
#          'over': 43,
#          'calm': 20,
#          'sea': 33,
#          'wafted': 4,
#          'land': 19,
#          'surpassing': 1,
#          'wonders': 4,
#          'every': 118,
#          'hitherto': 12,
#          'discovered': 34,
#          'habitable': 1,
#          'globe': 2,
#          'productions': 2,
#          'features': 6,
#          'example': 2,
#          'phænomena': 2,
#          'havenly': 1,
#          'bodies': 3,
#          'undoubtedly': 1,
#          'undiscovered': 2,
#          'solitudes': 1,
#          'what': 130,
#          'expected': 12,
#          'country': 54,
#          'eternal': 12,
#          'light': 42,
#          'discover': 16,
#          'wondrous': 6,
#          'power': 35,
#          'attracts': 1,
#          'needle': 1,
#          'regulate': 2,
#          'thousand': 21,
#          'celestial': 2,
#          'observations': 1,
#          'require': 1,
#          'voyage': 12,
#          'render': 11,
#          'seeming': 2,
#          'eccentricities': 1,
#          'consistent': 1,
#          'satiate': 2,
#          'ardent': 9,
#          'curiosity': 12,
#          'sight': 24,
#          'part': 37,
#          'world': 48,
#          'never': 66,
#          'before': 146,
#          'visited': 14,
#          'tread': 2,
#          'imprinted': 2,
#          'foot': 5,
#          'man': 126,
#          'enticements': 2,
#          'sufficient': 19,
#          'conquer': 1,
#          'fear': 36,
#          'danger': 11,
#          'death': 80,
#          'induce': 3,
#          'commence': 12,
#          'laborious': 3,
#          'joy': 38,
#          'child': 28,
#          'feels': 2,
#          'when': 337,
#          'he': 593,
#          'embarks': 1,
#          'little': 60,
#          'boat': 16,
#          'holiday': 1,
#          'mates': 1,
#          'expedition': 4,
#          'discovery': 17,
#          'up': 61,
#          'native': 28,
#          'river': 13,
#          'but': 664,
#          'supposing': 2,
#          'conjectures': 1,
#          'false': 4,
#          'contest': 1,
#          'inestimable': 1,
#          'benefit': 9,
#          'mankind': 11,
#          'last': 33,
#          'generation': 2,
#          'discovering': 3,
#          'passage': 8,
#          'near': 37,
#          'countries': 3,
#          'reach': 5,
#          'at': 320,
#          'months': 41,
#          'requisite': 1,
#          'ascertaining': 1,
#          'secret': 12,
#          'magnet': 1,
#          'if': 184,
#          'possible': 13,
#          'effected': 1,
#          'mine': 28,
#          'reflections': 16,
#          'dispelled': 1,
#          'agitation': 14,
#          'began': 28,
#          'letter': 24,
#          'heart': 72,
#          'glow': 1,
#          'enthusiasm': 9,
#          'elevates': 1,
#          'heaven': 17,
#          'nothing': 37,
#          'contributes': 1,
#          'much': 45,
#          'tranquillize': 1,
#          'steady': 2,
#          'purpose': 16,
#          'soul': 23,
#          'fix': 3,
#          'intellectual': 1,
#          'eye': 16,
#          'favourite': 21,
#          'early': 17,
#          'years': 45,
#          'read': 30,
#          'ardour': 9,
#          'accounts': 3,
#          'various': 24,
#          'voyages': 4,
#          'made': 65,
#          'prospect': 11,
#          'arriving': 1,
#          'pacific': 1,
#          'ocean': 11,
#          'through': 47,
#          'seas': 6,
#          'surround': 4,
#          'remember': 22,
#          'history': 17,
#          'purposes': 3,
#          'composed': 5,
#          'whole': 33,
#          'good': 38,
#          'uncle': 12,
#          "thomas's": 2,
#          'library': 2,
#          'education': 5,
#          'neglected': 7,
#          'passionately': 1,
#          'fond': 3,
#          'reading': 3,
#          'volumes': 2,
#          'study': 22,
#          'night': 84,
#          'familiarity': 1,
#          'them': 112,
#          'increased': 12,
#          'regret': 6,
#          'had': 662,
#          'felt': 76,
#          'learning': 5,
#          "father's": 17,
#          'dying': 5,
#          'injunction': 1,
#          'forbidden': 2,
#          'allow': 13,
#          'embark': 2,
#          'sea-faring': 1,
#          'life': 110,
#          'faded': 1,
#          'perused': 1,
#          'time': 111,
#          'poets': 3,
#          'whose': 47,
#          'effusions': 1,
#          'entranced': 1,
#          'lifted': 1,
#          'poet': 1,
#          'year': 8,
#          'lived': 23,
#          'creation': 17,
#          'imagined': 7,
#          'might': 111,
#          'obtain': 5,
#          'niche': 1,
#          'temple': 1,
#          'names': 11,
#          'homer': 1,
#          'consecrated': 1,
#          'well': 43,
#          'acquainted': 17,
#          'failure': 2,
#          'how': 93,
#          'heavily': 3,
#          'bore': 7,
#          'disappointment': 7,
#          'inherited': 2,
#          'fortune': 8,
#          'cousin': 33,
#          'thoughts': 39,
#          'turned': 20,
#          'channel': 1,
#          'earlier': 2,
#          'bent': 6,
#          'six': 5,
#          'since': 27,
#          'resolved': 33,
#          'even': 81,
#          'now': 163,
#          'hour': 22,
#          'dedicated': 2,
#          'great': 53,
#          'inuring': 1,
#          'body': 25,
#          'hardship': 1,
#          'whale-fishers': 1,
#          'several': 54,
#          'expeditions': 1,
#          'voluntarily': 1,
#          'endured': 24,
#          'famine': 2,
#          'thirst': 10,
#          'want': 10,
#          'sleep': 19,
#          'often': 57,
#          'worked': 8,
#          'harder': 1,
#          'common': 5,
#          'sailors': 10,
#          'during': 61,
#          'devoted': 12,
#          'hights': 1,
#          'mathematics': 3,
#          'theory': 5,
#          'medicine': 2,
#          'branches': 12,
#          'science': 27,
#          'naval': 1,
#          'adventurer': 1,
#          'derive': 2,
#          'greatest': 27,
#          'practical': 2,
#          'advantage': 4,
#          'twice': 2,
#          'actually': 2,
#          'hired': 6,
#          'undermate': 1,
#          'greenland': 1,
#          'whaler': 1,
#          'acquitted': 2,
#          'admiration': 12,
#          'must': 66,
#          'proud': 2,
#          'captain': 5,
#          'offered': 2,
#          'second': 3,
#          'dignity': 4,
#          'vessel': 16,
#          'entreated': 7,
#          'remain': 23,
#          'earnestness': 3,
#          'valuable': 3,
#          'did': 124,
#          'consider': 11,
#          'services': 2,
#          'deserve': 3,
#          'accomplish': 2,
#          'case': 9,
#          'luxury': 4,
#          'preferred': 2,
#          'glory': 7,
#          'enticement': 1,
#          'wealth': 7,
#          'placed': 24,
#          'path': 18,
#          'oh': 28,
#          'encouraging': 1,
#          'voice': 44,
#          'answer': 20,
#          'affirmative': 2,
#          'courage': 14,
#          'resolution': 9,
#          'firm': 6,
#          'hopes': 22,
#          'fluctuate': 1,
#          'spirits': 34,
#          'depressed': 6,
#          'about': 54,
#          'proceed': 5,
#          'long': 44,
#          'difficult': 2,
#          'emergencies': 1,
#          'demand': 10,
#          'fortitude': 4,
#          'required': 6,
#          'raise': 7,
#          'others': 26,
#          'sometimes': 59,
#          'sustain': 5,
#          "their's": 3,
#          'failing': 2,
#          'favourable': 7,
#          'period': 17,
#          'travelling': 2,
#          'russia': 2,
#          'fly': 7,
#          'quickly': 26,
#          'sledges': 1,
#          'motion': 6,
#          'pleasant': 11,
#          'opinion': 3,
#          'agreeable': 6,
#          'english': 11,
#          'stage-coach': 1,
#          'excessive': 3,
#          'wrapt': 3,
#          'furs': 2,
#          'dress': 7,
#          'adopted': 1,
#          'difference': 3,
#          'between': 16,
#          'walking': 7,
#          'deck': 8,
#          'remaining': 6,
#          'seated': 4,
#          'motionless': 6,
#          'hours': 34,
#          'exercise': 5,
#          'prevents': 2,
#          'blood': 18,
#          'freezing': 1,
#          'veins': 4,
#          'ambition': 6,
#          'lose': 7,
#          'post-road': 1,
#          'archangel': 5,
#          'depart': 8,
#          'latter': 12,
#          'town': 26,
#          'fortnight': 5,
#          'three': 12,
#          'weeks': 7,
#          'intention': 5,
#          'hire': 1,
#          'ship': 7,
#          'easily': 17,
#          'done': 10,
#          'paying': 1,
#          'insurance': 1,
#          'owner': 1,
#          'engage': 2,
#          'think': 28,
#          'necessary': 13,
#          'accustomed': 11,
#          'whale-fishing': 1,
#          'intend': 6,
#          'sail': 5,
#          'until': 55,
#          'month': 9,
#          'june': 1,
#          'return': 50,
#          'ah': 7,
#          'question': 9,
#          'succeed': 5,
#          'perhaps': 19,
#          'pass': 19,
#          'meet': 12,
#          'fail': 7,
#          'see': 52,
#          'again': 80,
#          'soon': 67,
#          'farewell': 9,
#          'excellent': 18,
#          'shower': 1,
#          'down': 36,
#          'blessings': 1,
#          'save': 6,
#          'testify': 1,
#          'gratitude': 6,
#          'love': 50,
#          'kindness': 24,
#          'affectionate': 10,
#          'brother': 21,
#          'r': 2,
#          'walton': 7,
#          '28th': 1,
#          'march': 4,
#          'slowly': 3,
#          'passes': 2,
#          'encompassed': 3,
#          'step': 5,
#          'taken': 29,
#          'occupied': 20,
#          'collecting': 5,
#          'engaged': 18,
#          'appear': 20,
#          'men': 40,
#          'depend': 3,
#          'certainly': 16,
#          'possessed': 35,
#          'dauntless': 1,
#          'able': 7,
#          'satisfy': 6,
#          'absence': 10,
#          'object': 19,
#          'severe': 7,
#          'friend': 70,
#          'glowing': 1,
#          'none': 18,
#          'participate': 2,
#          'assailed': 1,
#          'endeavour': 14,
#          'dejection': 4,
#          'commit': 4,
#          'paper': 2,
#          'true': 21,
#          'poor': 41,
#          'medium': 1,
#          'communication': 4,
#          'company': 6,
#          'could': 180,
#          'sympathize': 5,
#          'eyes': 99,
#          'reply': 4,
#          'deem': 1,
#          'romantic': 3,
#          'bitterly': 10,
#          'gentle': 37,
#          'courageous': 1,
#          'cultivated': 4,
#          'capacious': 2,
#          'tastes': 2,
#          'like': 54,
#          'approve': 1,
#          'amend': 1,
#          'plans': 7,
#          'repair': 1,
#          'faults': 1,
#          'too': 28,
#          'execution': 7,
#          'impatient': 3,
#          'difficulties': 2,
#          'still': 62,
#          'greater': 23,
#          'self-educated': 2,
#          'fourteen': 1,
#          'ran': 7,
#          'wild': 9,
#          'books': 13,
#          'age': 13,
#          'celebrated': 2,
#          'ceased': 9,
#          'important': 1,
#          'benefits': 1,
#          'perceived': 25,
#          'necessity': 3,
#          'becoming': 3,
#          'languages': 5,
#          'twenty-eight': 1,
#          'reality': 10,
#          'illiterate': 1,
#          'school-boys': 1,
#          'fifteen': 2,
#          'thought': 71,
#          'extended': 2,
#          'painters': 1,
#          'call': 13,
#          'keeping': 2,
#          'greatly': 12,
#          'need': 6,
#          'sense': 6,
#          'enough': 12,
#          'despise': 1,
#          'useless': 9,
#          'complaints': 3,
#          'find': 25,
#          'wide': 7,
#          'merchants': 1,
#          'seamen': 1,
#          'feelings': 80,
#          'unallied': 1,
#          'dross': 1,
#          'beat': 5,
#          'rugged': 3,
#          'bosoms': 1,
#          'lieutenant': 2,
#          'instance': 1,
#          'wonderful': 17,
#          'madly': 1,
#          'desirous': 1,
#          'englishman': 2,
#          'midst': 3,
#          'national': 1,
#          'professional': 1,
#          'prejudices': 2,
#          'unsoftened': 1,
#          'cultivation': 4,
#          'retains': 1,
#          'noblest': 1,
#          'endowments': 1,
#          'humanity': 6,
#          'him': 212,
#          'board': 5,
#          'whale': 1,
#          'finding': 8,
#          'unemployed': 1,
#          'city': 12,
#          'assist': 6,
#          'master': 8,
#          'person': 17,
#          'disposition': 8,
#          'remarkable': 2,
#          'gentleness': 9,
#          'mildness': 4,
#          'discipline': 1,
#          'indeed': 58,
#          'amiable': 19,
#          'hunt': 1,
#          'almost': 39,
#          'because': 18,
#          'endure': 17,
#          'spill': 1,
#          'moreover': 1,
#          'heroically': 1,
#          'generous': 6,
#          'ago': 8,
#          'loved': 25,
#          'young': 31,
#          'russian': 1,
#          'lady': 11,
#          'moderate': 4,
#          'having': 22,
#          'amassed': 1,
#          'considerable': 6,
#          'sum': 5,
#          'prize-money': 2,
#          'father': 128,
#          'girl': 28,
#          'consented': 6,
#          'match': 1,
#          'saw': 94,
#          'mistress': 3,
#          'once': 30,
#          'destined': 6,
#          'ceremony': 3,
#          'she': 247,
#          'bathed': 1,
#          'tears': 31,
#          'throwing': 2,
#          'herself': 17,
#          'feet': 13,
#          'spare': 2,
#          'her': 341,
#          'confessing': 1,
#          'same': 58,
#          'another': 49,
#          'consent': 12,
#          'union': 13,
#          'reassured': 1,
#          'suppliant': 1,
#          'being': 85,
#          'informed': 4,
#          'name': 17,
#          'lover': 7,
#          'instantly': 17,
#          'abandoned': 3,
#          'pursuit': 15,
#          'bought': 2,
#          'farm': 1,
#          'money': 8,
#          'designed': 1,
#          'remainder': 5,
#          'bestowed': 11,
#          'rival': 1,
#          'together': 8,
#          'remains': 13,
#          'purchase': 1,
#          'stock': 2,
#          'then': 101,
#          'himself': 35,
#          'solicited': 2,
#          "woman's": 1,
#          'marriage': 15,
#          'old': 50,
#          'decidedly': 1,
#          'refused': 3,
#          'thinking': 2,
#          'bound': 12,
#          'honour': 11,
#          'found': 84,
#          'inexorable': 2,
#          'quitted': 24,
#          'returned': 31,
#          'heard': 63,
#          'former': 10,
#          'married': 4,
#          'inclinations': 2,
#          'noble': 9,
#          'fellow': 7,
#          'exclaim': 1,
#          'scarcely': 13,
#          'idea': 31,
#          'beyond': 8,
#          'rope': 1,
#          'shroud': 2,
#          'suppose': 7,
#          'complain': 1,
#          ...})

# %%
t.graph_ties()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ryan/github/totality/README.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/totality/README.ipynb#ch0000016?line=0'>1</a> t.graph_ties()
#
# File ~/github/totality/totality/texts/text.py:315, in BaseText.graph_ties(self, **kwargs)
#     <a href='file:///Users/ryan/github/totality/totality/texts/text.py?line=312'>313</a> for pathd in traversal_data.get('paths',[]):
#     <a href='file:///Users/ryan/github/totality/totality/texts/text.py?line=313'>314</a>     for edged in pathd.get('edges'):
# --> <a href='file:///Users/ryan/github/totality/totality/texts/text.py?line=314'>315</a>         t1=Textspace().get(edged.get('_from'))
#     <a href='file:///Users/ryan/github/totality/totality/texts/text.py?line=315'>316</a>         t2=Textspace().get(edged.get('_to'))
#     <a href='file:///Users/ryan/github/totality/totality/texts/text.py?line=316'>317</a>         g.add_edge(t1.nice, t2.nice, **edged)
#
# File ~/github/totality/totality/database/docspace.py:84, in DocspaceModel.get(self, id, default)
#      <a href='file:///Users/ryan/github/totality/totality/database/docspace.py?line=81'>82</a> if id in TEXT_CACHE: return TEXT_CACHE[id]
#      <a href='file:///Users/ryan/github/totality/totality/database/docspace.py?line=82'>83</a> if id in CORPUS_CACHE: return CORPUS_CACHE[id]
# ---> <a href='file:///Users/ryan/github/totality/totality/database/docspace.py?line=83'>84</a> if self.coll.has(id): return Text(**self.coll.get(id))
#      <a href='file:///Users/ryan/github/totality/totality/database/docspace.py?line=85'>86</a> if Relspace().coll.has(id): return Text(**Relspace().coll.get(id))
#      <a href='file:///Users/ryan/github/totality/totality/database/docspace.py?line=87'>88</a> return default
#
# File ~/miniforge3/lib/python3.9/site-packages/arango/collection.py:549, in Collection.has(self, document, rev, check_rev)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/collection.py?line=545'>546</a>         raise DocumentInError(resp, request)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/collection.py?line=546'>547</a>     return bool(resp.body)
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/collection.py?line=548'>549</a> return self._execute(request, response_handler)
#
# File ~/miniforge3/lib/python3.9/site-packages/arango/api.py:74, in ApiGroup._execute(self, request, response_handler)
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=62'>63</a> def _execute(
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=63'>64</a>     self, request: Request, response_handler: Callable[[Response], T]
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=64'>65</a> ) -> Result[T]:
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=65'>66</a>     """Execute an API.
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=66'>67</a>
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=67'>68</a>     :param request: HTTP request.
#    (...)
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=71'>72</a>     :return: API execution result.
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=72'>73</a>     """
# ---> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/api.py?line=73'>74</a>     return self._executor.execute(request, response_handler)
#
# File ~/miniforge3/lib/python3.9/site-packages/arango/executor.py:64, in DefaultApiExecutor.execute(self, request, response_handler)
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=54'>55</a> def execute(self, request: Request, response_handler: Callable[[Response], T]) -> T:
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=55'>56</a>     """Execute an API request and return the result.
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=56'>57</a>
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=57'>58</a>     :param request: HTTP request.
#    (...)
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=61'>62</a>     :return: API execution result.
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=62'>63</a>     """
# ---> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=63'>64</a>     resp = self._conn.send_request(request)
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/executor.py?line=64'>65</a>     return response_handler(resp)
#
# File ~/miniforge3/lib/python3.9/site-packages/arango/connection.py:275, in BasicConnection.send_request(self, request)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=266'>267</a> """Send an HTTP request to ArangoDB server.
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=267'>268</a>
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=268'>269</a> :param request: HTTP request.
#    (...)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=271'>272</a> :rtype: arango.response.Response
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=272'>273</a> """
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=273'>274</a> host_index = self._host_resolver.get_host_index()
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=274'>275</a> return self.process_request(host_index, request, auth=self._auth)
#
# File ~/miniforge3/lib/python3.9/site-packages/arango/connection.py:132, in BaseConnection.process_request(self, host_index, request, auth)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=129'>130</a> while tries < self._host_resolver.max_tries:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=130'>131</a>     try:
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=131'>132</a>         resp = self._http.send_request(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=132'>133</a>             session=self._sessions[host_index],
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=133'>134</a>             method=request.method,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=134'>135</a>             url=self._url_prefixes[host_index] + request.endpoint,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=135'>136</a>             params=request.params,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=136'>137</a>             data=self.normalize_data(request.data),
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=137'>138</a>             headers=request.headers,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=138'>139</a>             auth=auth,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=139'>140</a>         )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=141'>142</a>         return self.prep_response(resp, request.deserialize)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/connection.py?line=142'>143</a>     except ConnectionError:
#
# File ~/miniforge3/lib/python3.9/site-packages/arango/http.py:124, in DefaultHTTPClient.send_request(self, session, method, url, headers, params, data, auth)
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=94'>95</a> def send_request(
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=95'>96</a>     self,
#      <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=96'>97</a>     session: Session,
#    (...)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=102'>103</a>     auth: Optional[Tuple[str, str]] = None,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=103'>104</a> ) -> Response:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=104'>105</a>     """Send an HTTP request.
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=105'>106</a>
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=106'>107</a>     :param session: Requests session object.
#    (...)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=121'>122</a>     :rtype: arango.response.Response
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=122'>123</a>     """
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=123'>124</a>     response = session.request(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=124'>125</a>         method=method,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=125'>126</a>         url=url,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=126'>127</a>         params=params,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=127'>128</a>         data=data,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=128'>129</a>         headers=headers,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=129'>130</a>         auth=auth,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=130'>131</a>         timeout=self.REQUEST_TIMEOUT,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=131'>132</a>     )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=132'>133</a>     return Response(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=133'>134</a>         method=method,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=134'>135</a>         url=response.url,
#    (...)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=138'>139</a>         raw_body=response.text,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/arango/http.py?line=139'>140</a>     )
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=523'>524</a> send_kwargs = {
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=524'>525</a>     'timeout': timeout,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=525'>526</a>     'allow_redirects': allow_redirects,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=526'>527</a> }
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=527'>528</a> send_kwargs.update(settings)
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=528'>529</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=530'>531</a> return resp
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=641'>642</a> start = preferred_clock()
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=643'>644</a> # Send the request
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=644'>645</a> r = adapter.send(request, **kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=646'>647</a> # Total elapsed time of the request (approximately)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/sessions.py?line=647'>648</a> elapsed = preferred_clock() - start
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=437'>438</a> try:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=438'>439</a>     if not chunked:
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=439'>440</a>         resp = conn.urlopen(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=440'>441</a>             method=request.method,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=441'>442</a>             url=url,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=442'>443</a>             body=request.body,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=443'>444</a>             headers=request.headers,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=444'>445</a>             redirect=False,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=445'>446</a>             assert_same_host=False,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=446'>447</a>             preload_content=False,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=447'>448</a>             decode_content=False,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=448'>449</a>             retries=self.max_retries,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=449'>450</a>             timeout=timeout
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=450'>451</a>         )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=452'>453</a>     # Send the request.
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=453'>454</a>     else:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/requests/adapters.py?line=454'>455</a>         if hasattr(conn, 'proxy_pool'):
#
# File ~/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=695'>696</a>     self._prepare_proxy(conn)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=697'>698</a> # Make the request on the httplib connection object.
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=698'>699</a> httplib_response = self._make_request(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=699'>700</a>     conn,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=700'>701</a>     method,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=701'>702</a>     url,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=702'>703</a>     timeout=timeout_obj,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=703'>704</a>     body=body,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=704'>705</a>     headers=headers,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=705'>706</a>     chunked=chunked,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=706'>707</a> )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=708'>709</a> # If we're going to release the connection in ``finally:``, then
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=709'>710</a> # the response doesn't need to know about the connection. Otherwise
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=710'>711</a> # it will also try to release it and we'll have a double-release
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=711'>712</a> # mess.
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=712'>713</a> response_conn = conn if not release_conn else None
#
# File ~/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py:445, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=439'>440</a>             httplib_response = conn.getresponse()
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=440'>441</a>         except BaseException as e:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=441'>442</a>             # Remove the TypeError from the exception chain in
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=442'>443</a>             # Python 3 (including for exceptions like SystemExit).
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=443'>444</a>             # Otherwise it looks like a bug in the code.
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=444'>445</a>             six.raise_from(e, None)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=445'>446</a> except (SocketTimeout, BaseSSLError, SocketError) as e:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=446'>447</a>     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py:440, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=436'>437</a> except TypeError:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=437'>438</a>     # Python 3
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=438'>439</a>     try:
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=439'>440</a>         httplib_response = conn.getresponse()
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=440'>441</a>     except BaseException as e:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=441'>442</a>         # Remove the TypeError from the exception chain in
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=442'>443</a>         # Python 3 (including for exceptions like SystemExit).
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=443'>444</a>         # Otherwise it looks like a bug in the code.
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py?line=444'>445</a>         six.raise_from(e, None)
#
# File ~/miniforge3/lib/python3.9/http/client.py:1371, in HTTPConnection.getresponse(self)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=1368'>1369</a> try:
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=1369'>1370</a>     try:
# -> <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=1370'>1371</a>         response.begin()
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=1371'>1372</a>     except ConnectionError:
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=1372'>1373</a>         self.close()
#
# File ~/miniforge3/lib/python3.9/http/client.py:319, in HTTPResponse.begin(self)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=316'>317</a> # read until we get a non-100 response
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=317'>318</a> while True:
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=318'>319</a>     version, status, reason = self._read_status()
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=319'>320</a>     if status != CONTINUE:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=320'>321</a>         break
#
# File ~/miniforge3/lib/python3.9/http/client.py:280, in HTTPResponse._read_status(self)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=278'>279</a> def _read_status(self):
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=279'>280</a>     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=280'>281</a>     if len(line) > _MAXLINE:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/http/client.py?line=281'>282</a>         raise LineTooLong("status line")
#
# File ~/miniforge3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/socket.py?line=701'>702</a> while True:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/socket.py?line=702'>703</a>     try:
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/socket.py?line=703'>704</a>         return self._sock.recv_into(b)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/socket.py?line=704'>705</a>     except timeout:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/socket.py?line=705'>706</a>         self._timeout_occurred = True
#
# KeyboardInterrupt:
